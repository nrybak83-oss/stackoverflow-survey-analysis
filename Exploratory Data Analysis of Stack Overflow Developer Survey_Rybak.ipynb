# %%
# Імпортування бібліотеки
import pandas as pd

# Читання файлів з використанням стандартного декодування
df = pd.read_csv(r"C:\Users\Наталія\Downloads\stack-overflow-developer-survey-2025\survey_results_public.csv", encoding = 'utf-8')
df1 = pd.read_csv(r"C:\Users\Наталія\Downloads\stack-overflow-developer-survey-2025\survey_results_schema.csv", encoding = 'utf-8')
# Out:
# C:\Users\Наталія\AppData\Local\Temp\ipykernel_10392\821008045.py:5: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Наталія\Downloads\stack-overflow-developer-survey-2025\survey_results_public.csv", encoding = 'utf-8')

# %%
# Налаштування параметрів для відображення всіх колонок
pd.set_option('display.max_columns',None)

# %%
# DataFrame, oпитування респондентів
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
# DataFrame з питаннями опитування
df1
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %% [markdown]
# Завдання 1. Підрахунок загальної кількості респондентів

# %%
# .nunique() - метод Series, який підраховує кількість унікальних значень у стовпці ResponseId
total_respondents = df['ResponseId'].nunique()

print(f"Загальна кількість унікальних респондентів: {total_respondents}")
# Out:
# Загальна кількість унікальних респондентів: 49191

# %% [raw]
# Завдання 2. Аналіз повноти відповідей респондентів

# %%
# questions - створюємо множину назв питань, які присутні одночасно в qname та серед стовпців df
qname_set = set(df1['qname'].unique())

# Знаходимо перетин із df.columns, щоб отримати лише ті питання, що реально є в df
questions = qname_set.intersection(set(df.columns))

# Видаляємо рядки, де є пропуски (NaN) у вибраних стовпцях
df_complete = df.dropna(subset=list(questions))

# Рахуємо кількість респондентів, які відповіли на всі питання
complete_responses_count = df_complete.shape[0]

print(f"Кількість спільних питань: {len(questions)}")
print(f"Респондентів, які відповіли на всі ці питання: {complete_responses_count}")
# Out:
# Кількість спільних питань: 126
# Респондентів, які відповіли на всі ці питання: 0

# %% [raw]
# Завдання 3. Статистичний аналіз досвіду респондентів

# %%
# Обчислення мір центральної тенденції для WorkExp
print(f'Міри центральної тенденції:')

# Середнє значення (mean) з округленням до 1 знака
print(f'Mean: {round(df["WorkExp"].mean(), 1)}')

# Медіана (median)
print(f'Median: {df["WorkExp"].median()}')

# Мода (mode) - беремо перший елемент [0], бо мода повертає декілька значень
print(f'Mode: {df["WorkExp"].mode()[0]}')
# Out:
# Міри центральної тенденції:
# Mean: 13.4
# Median: 10.0
# Mode: 10.0

# %% [raw]
# Завдання 4. Аналіз віддаленої роботи

# %%
# Рахуємо кількість респондентів, які працюють віддалено
# Створюємо фільтр, де значення в колонці RemoteWork дорівнює 'Remote'
remote_workers_count = df[df['RemoteWork'] == 'Remote'].shape[0]

print(f"Кількість респондентів, які працюють віддалено: {remote_workers_count}")
# Out:
# Кількість респондентів, які працюють віддалено: 10931

# %% [raw]
# Завдання 5. Визначення популярності Python

# %%
# Створюємо стовпець worked_with_python,
# використовуємо str.contains() для пошуку слова 'python', не враховуємо регістр case=False, na=False автоматично замінює NaN на False
df['worked_with_python'] = df['LanguageHaveWorkedWith'].str.contains('python', case=False, na=False)

# Рахуємо кількість тих, хто працює з Python
python_users_count = df['worked_with_python'].sum()

# Обчислюємо відсоток від загальної кількості респондентів
total_respondents = len(df)
python_percentage = (python_users_count / total_respondents) * 100

print(f'Відсоток респондентів, які працюють з Python: {round(python_percentage, 2)}%')
# Out:
# Відсоток респондентів, які працюють з Python: 37.54%

# %% [raw]
# Завдання 6. Аналіз шляхів навчання програмуванню

# %%
# Створюємо новий стовпець Learned_with_online_courses
# Шукаємо 'Online Courses' у стовпці LearnCode
df['Learned_with_online_courses'] = df['LearnCode'].str.contains('Online Courses', case=False, na=False)

# Підраховуємо кількість респондентів (сумуємо True)
online_learners_count = df['Learned_with_online_courses'].sum()

# Виводимо результат
print(f"Кількість респондентів, які навчалися через онлайн-курси: {online_learners_count}")
# Out:
# Кількість респондентів, які навчалися через онлайн-курси: 10973

# %% [raw]
# Завдання 7. Географічний аналіз компенсації Python-розробників

# %%
# Відбираємо лише тих, хто працює з Python (стовпець було створено у Завданні 5)
python_df = df[df['worked_with_python'] == True].copy()

# Видаляємо рядки, де не вказана компенсація 
python_df = python_df.dropna(subset=['ConvertedCompYearly'])

# Групуємо за країною та обчислюємо середнє і медіану для ConvertedCompYearly
py_progers_by_country = python_df.groupby('Country')['ConvertedCompYearly'].agg(['mean', 'median'])

# Сортуємо для зручності (наприклад, за медіаною від вищої до нижчої)
py_progers_by_country = py_progers_by_country.sort_values(by='median', ascending=False)

# Виводимо результат
print("Статистика компенсації Python-розробників за країнами:")
print(py_progers_by_country)
# Out:
# Статистика компенсації Python-розробників за країнами:
#                                    mean    median
# Country
# Oman                      390135.000000  390135.0
# Andorra                   226103.500000  226103.5
# United States of America  173298.590211  150000.0
# Israel                    135828.365385  142594.0
# Switzerland               156456.600000  142592.0
# ...                                 ...       ...
# Cambodia                    1270.000000    1270.0
# Afghanistan                22328.666667    1000.0
# Togo                         354.000000     354.0
# Palestine                     78.000000      78.0
# Antigua and Barbuda            1.000000       1.0
#
# [153 rows x 2 columns]

# %% [raw]
# Завдання 8. Аналіз освіти найбільш оплачуваних спеціалістів

# %%
# Вибираємо потрібні стовпці та сортуємо за спаданням компенсації
top_paid_df = df[['ResponseId', 'EdLevel', 'ConvertedCompYearly']].sort_values(by='ConvertedCompYearly', ascending=False)

# Оновлюємо індекси і беремо топ-5
top_5_education = top_paid_df.reset_index(drop=True).head(5)

# Виводимо результат
print("Рівень освіти 5 респондентів з найбільшою компенсацією:")
print(top_5_education)
# Out:
# Рівень освіти 5 респондентів з найбільшою компенсацією:
#    ResponseId                                          EdLevel  \
# 0       34268              Associate degree (A.A., A.S., etc.)
# 1       28701  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2       43144              Associate degree (A.A., A.S., etc.)
# 3       35354     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       45972  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#    ConvertedCompYearly
# 0           50000000.0
# 1           33552715.0
# 2           18387548.0
# 3           15430267.0
# 4           13921760.0

# %% [raw]
# *Завдання 9. Аналіз популярності Python по віковим категоріям

# %%
# Групуємо дані за віковою категорією
# Рахуємо загальну кількість респондентів у кожній віковій групі
age_groups_total = df.groupby('Age')['ResponseId'].count()

# Рахуємо кількість користувачів Python у кожній віковій групі
# Використовуємо стовпець worked_with_python, який ми створили раніше
age_groups_python = df.groupby('Age')['worked_with_python'].sum()

# Обчислюємо відсоток
python_popularity_by_age = (age_groups_python / age_groups_total) * 100

# Формуємо підсумкову таблицю
age_analysis = pd.DataFrame({
    'Total Respondents': age_groups_total,
    'Python Users': age_groups_python,
    'Percentage (%)': round(python_popularity_by_age, 2)
})

# Сортуємо за відсотком
print("Популярність Python за віковими категоріями:")
print(age_analysis.sort_values(by='Percentage (%)', ascending=False))
# Out:
# Популярність Python за віковими категоріями:
#                    Total Respondents  Python Users  Percentage (%)
# Age
# 18-24 years old                 9210          3684           40.00
# 45-54 years old                 6275          2424           38.63
# 55-64 years old                 2626           978           37.24
# 25-34 years old                16519          6102           36.94
# 35-44 years old                13241          4862           36.72
# 65 years or older                942           298           31.63
# Prefer not to say                378           118           31.22

# %% [raw]
# Завдання 10. Аналіз індустрій серед високооплачуваних віддалених працівників

# %%
# Розраховуємо 75-й перцентиль (квантиль 0.75) для ConvertedCompYearly
# Це сума, вище якої заробляють лише 25% найбільш високооплачуваних респондентів
comp_75_percentile = df['ConvertedCompYearly'].quantile(0.75)

# Фільтруємо за декількома показниками:
# - Компенсація >= 75 перцентиля
# - Працюють віддалено
high_paid_remote = df[
    (df['ConvertedCompYearly'] >= comp_75_percentile) & 
    (df['RemoteWork'] == 'Remote')
].copy()

# Визначаємо найрозповсюдженіші індустрії
# Використовуємо value_counts(), який автоматично сортує за частотою (від більшого до меншого)
top_industries = high_paid_remote['Industry'].value_counts()

# Виводимо результати
print(f"Поріг 75-го перцентиля: {round(comp_75_percentile, 2)}")
print("\nНайпопулярніші індустрії серед високооплачуваних віддалених працівників:")
print(top_industries.head(10))
# Out:
# Поріг 75-го перцентиля: 120596.0
#
# Найпопулярніші індустрії серед високооплачуваних віддалених працівників:
# Industry
# Software Development                          1186
# Fintech                                        190
# Healthcare                                     188
# Other:                                         176
# Internet, Telecomm or Information Services     138
# Banking/Financial Services                      88
# Government                                      78
# Media & Advertising Services                    75
# Retail and Consumer Services                    65
# Transportation, or Supply Chain                 63
# Name: count, dtype: int64
